# %% [markdown]
# <a href="https://colab.research.google.com/github/HannahShaw21/Public-Repo-4-Hannah/blob/main/Homework/HW2_Hannah_Shaw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import statsmodels.api as sm
boston = sm.datasets.get_rdataset("Boston", package="MASS").data

# %%
X = boston[['lstat']]   # predictor - A socioeconomic feature. Higher values → neighborhoods with more lower-income residents.
y = boston['medv']      # response - Median value of owner-occupied homes (in $1000s)

# %%
import numpy as np
import pandas as pd


k_values = np.arange(1, 201, 5)
n = len(X)
split = n // 2
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# %% [markdown]
# # Homework 2.a

# %%
# Homework 2.a - No AI support allowed, please get the info you need from https://numpy.org/doc/stable/reference/random/generated/numpy.random.choice.html
  # generate an array of size split (n//2) and save the array as split_idx
split_idx = np.random.choice(n, size=split, replace=False, p=None)

  # make a new random X_train, y_train by selecting the data on the rows corresponding to split_idx
X_train, y_train = pd.DataFrame(X.iloc[split_idx]), pd.DataFrame(y.iloc[split_idx])

  # make a new test dataset X_test, y_test by selecting the data "not" on the rows corresponding to split_idx
X_test, y_test = pd.DataFrame(X.iloc[~split_idx]), pd.DataFrame(y.iloc[~split_idx])

# %%
from sklearn.neighbors import KNeighborsRegressor

# Fit KNN with k = 30
knn = KNeighborsRegressor(n_neighbors=30)
knn.fit(X_train, y_train)

# Perform prediction
fitted_values = knn.predict(X_train)

# Combine results into DataFrame
results = pd.DataFrame({'predictor_lstat': X_train.values.ravel(), 'predicted_medv': fitted_values.ravel()})
print(results.head())
# Out:
#    predictor_lstat  predicted_medv
# 0            12.26       19.993333
# 1             7.39       26.340000
# 2             8.93       23.710000
# 3             4.08       37.003333
# 4             5.57       28.276667

# %% [markdown]
# # Homework 2.b

# %%
X_test = X_test.to_csv(header=None)
print(X_test)
# Out:
# 374,37.97
# 346,12.67
# 200,4.45
# 309,9.97
# 150,14.1
# 400,26.77
# 8,29.93
# 287,7.14
# 270,13.0
# 102,10.63
# 147,29.53
# 73,7.54
# 139,18.46
# 223,7.6
# 30,22.6
# 142,26.82
# 360,7.79
# 409,19.78
# 196,4.08
# 266,14.79
# 468,18.13
# 101,7.67
# 474,18.14
# 2,4.03
# 499,15.1
# 169,11.32
# 166,3.7
# 219,10.5
# 155,15.02
# 366,14.0
# 108,12.27
# 199,4.56
# 263,11.25
# 103,13.44
# 462,13.99
# 353,4.5
# 72,5.52
# 497,14.1
# 229,3.76
# 105,16.47
# 304,6.93
# 113,17.09
# 403,19.77
# 92,8.16
# 298,4.97
# 398,30.59
# 66,10.24
# 107,14.09
# 431,19.69
# 94,10.59
# 356,17.6
# 308,4.54
# 181,9.45
# 171,12.03
# 380,17.21
# 361,14.19
# 243,5.19
# 294,10.4
# 209,23.09
# 210,17.27
# 450,17.44
# 486,14.98
# 377,21.24
# 451,17.73
# 455,18.13
# 99,6.19
# 442,16.59
# 3,2.94
# 487,11.45
# 295,6.27
# 410,10.11
# 395,17.12
# 236,9.54
# 347,6.36
# 307,7.53
# 426,15.69
# 417,26.64
# 282,3.01
# 461,14.65
# 362,10.19
# 253,3.54
# 286,12.93
# 127,17.19
# 437,26.45
# 25,16.51
# 186,4.45
# 135,16.96
# 283,3.16
# 350,5.98
# 425,24.39
# 384,30.63
# 471,12.87
# 480,10.74
# 41,4.84
# 472,14.36
# 162,1.92
# 28,12.8
# 88,5.5
# 427,14.52
# 277,4.16
# 443,18.85
# 290,3.33
# 177,6.29
# 433,16.22
# 71,9.88
# 117,10.3
# 9,17.1
# 1,9.14
# 40,1.98
# 447,16.44
# 174,9.64
# 191,4.69
# 137,14.59
# 235,10.88
# 250,5.9
# 489,23.97
# 352,7.79
# 381,21.08
# 407,12.13
# 83,7.51
# 215,9.47
# 149,21.45
# 205,10.87
# 228,3.92
# 190,5.1
# 246,9.16
# 11,13.27
# 401,20.32
# 23,19.88
# 343,7.18
# 217,9.69
# 20,21.02
# 504,6.48
# 491,18.07
# 207,18.06
# 411,21.22
# 204,2.88
# 69,8.79
# 19,11.28
# 167,12.14
# 213,9.38
# 34,20.34
# 50,13.45
# 490,29.68
# 244,12.5
# 122,17.93
# 321,6.87
# 202,3.11
# 267,7.44
# 303,4.86
# 48,30.81
# 160,5.5
# 97,4.21
# 214,29.55
# 65,4.67
# 482,7.01
# 365,7.12
# 446,17.79
# 500,14.33
# 315,11.5
# 120,14.37
# 301,9.5
# 6,12.43
# 106,18.66
# 124,17.58
# 493,12.01
# 123,25.41
# 477,24.91
# 393,15.17
# 322,7.7
# 222,9.93
# 132,11.12
# 501,9.67
# 188,4.56
# 74,6.78
# 453,16.74
# 54,14.8
# 185,13.15
# 84,9.62
# 313,7.9
# 118,15.37
# 258,7.79
# 354,8.05
# 198,6.62
# 405,22.98
# 341,5.49
# 478,18.03
# 386,28.28
# 502,9.08
# 144,29.29
# 429,24.08
# 175,5.33
# 16,6.58
# 422,14.1
# 318,10.36
# 152,12.12
# 251,3.59
# 299,4.74
# 240,11.38
# 76,11.97
# 145,27.8
# 423,23.29
# 424,17.16
# 275,2.98
# 255,9.25
# 357,13.27
# 165,9.81
# 339,9.74
# 82,6.72
# 93,6.21
# 133,15.03
# 459,14.7
# 430,17.64
# 218,17.92
# 285,8.23
# 406,23.34
# 17,14.67
# 492,13.35
# 264,8.1
# 208,14.66
# 414,36.98
# 114,10.45
# 371,9.53
# 428,21.52
# 404,27.38
# 444,23.79
# 479,13.11
# 376,23.24
# 143,26.42
# 434,15.17
# 233,3.95
# 164,11.64
# 46,14.15
# 89,5.7
# 448,18.13
# 43,7.44
# 454,18.71
# 176,10.11
# 325,5.08
# 319,12.73
# 140,24.16
# 440,22.11
# 31,13.04
# 416,25.79
# 211,23.98
# 245,18.46
# 367,13.33
# 305,8.93
# 249,6.56
# 327,12.79
# 415,29.05
# 21,13.83
# 110,13.0

# %%
X_train = X_train.to_csv(header=None)
print(X_train)
# Out:
# 131,12.26
# 159,7.39
# 305,8.93
# 196,4.08
# 355,5.57
# 105,16.47
# 497,14.1
# 218,17.92
# 235,10.88
# 403,19.77
# 358,11.48
# 432,12.03
# 366,14.0
# 282,3.01
# 475,24.1
# 363,14.64
# 145,27.8
# 96,11.34
# 309,9.97
# 239,7.37
# 37,8.77
# 404,27.38
# 31,13.04
# 503,5.64
# 6,12.43
# 336,9.8
# 339,9.74
# 286,12.93
# 350,5.98
# 139,18.46
# 397,19.92
# 306,6.47
# 242,11.22
# 402,20.31
# 43,7.44
# 152,12.12
# 433,16.22
# 8,29.93
# 276,6.05
# 400,26.77
# 201,7.43
# 392,25.68
# 102,10.63
# 413,20.08
# 207,18.06
# 107,14.09
# 439,22.88
# 398,30.59
# 74,6.78
# 411,21.22
# 149,21.45
# 197,8.61
# 324,6.12
# 334,6.75
# 125,14.81
# 144,29.29
# 262,5.91
# 211,23.98
# 296,7.39
# 295,6.27
# 55,4.81
# 19,11.28
# 128,15.39
# 54,14.8
# 50,13.45
# 406,23.34
# 63,9.5
# 502,9.08
# 18,11.69
# 210,17.27
# 95,6.65
# 110,13.0
# 269,13.65
# 158,6.43
# 198,6.62
# 79,9.1
# 88,5.5
# 223,7.6
# 44,9.55
# 143,26.42
# 252,3.53
# 219,10.5
# 378,23.69
# 68,13.09
# 480,10.74
# 319,12.73
# 370,2.96
# 222,9.93
# 155,15.02
# 80,5.29
# 121,14.27
# 34,20.34
# 25,16.51
# 464,13.22
# 33,18.35
# 343,7.18
# 477,24.91
# 417,26.64
# 78,12.34
# 228,3.92
# 62,6.73
# 215,9.47
# 328,9.97
# 72,5.52
# 434,15.17
# 388,30.62
# 496,21.14
# 504,6.48
# 465,14.13
# 58,6.86
# 331,12.43
# 314,9.28
# 368,3.26
# 270,13.0
# 255,9.25
# 16,6.58
# 153,15.79
# 124,17.58
# 98,3.57
# 422,14.1
# 290,3.33
# 356,17.6
# 300,6.07
# 277,4.16
# 315,11.5
# 259,6.9
# 494,13.59
# 104,12.33
# 482,7.01
# 162,1.92
# 288,7.6
# 485,10.58
# 1,9.14
# 14,10.26
# 298,4.97
# 94,10.59
# 301,9.5
# 436,18.05
# 486,14.98
# 338,8.51
# 292,4.7
# 471,12.87
# 455,18.13
# 15,8.47
# 261,7.26
# 383,24.56
# 184,13.98
# 303,4.86
# 238,6.36
# 202,3.11
# 457,16.94
# 345,10.53
# 408,26.4
# 291,3.56
# 440,22.11
# 23,19.88
# 140,24.16
# 59,9.22
# 5,5.21
# 190,5.1
# 385,30.81
# 204,2.88
# 499,15.1
# 399,29.97
# 381,21.08
# 12,15.71
# 382,23.6
# 28,12.8
# 112,16.21
# 183,5.68
# 283,3.16
# 373,34.77
# 4,5.33
# 317,15.94
# 431,19.69
# 52,5.28
# 451,17.73
# 320,7.2
# 421,15.7
# 192,2.87
# 387,31.99
# 247,10.15
# 151,13.28
# 307,7.53
# 100,9.42
# 164,11.64
# 27,17.28
# 119,13.61
# 3,2.94
# 361,14.19
# 76,11.97
# 330,9.09
# 489,23.97
# 83,7.51
# 187,6.68
# 353,4.5
# 254,6.57
# 206,10.97
# 265,10.45
# 429,24.08
# 360,7.79
# 82,6.72
# 81,7.22
# 230,11.65
# 250,5.9
# 148,28.32
# 340,9.29
# 166,3.7
# 423,23.29
# 412,34.37
# 372,8.88
# 46,14.15
# 75,8.94
# 287,7.14
# 220,9.71
# 99,6.19
# 488,18.06
# 13,8.26
# 241,12.4
# 297,15.84
# 91,8.2
# 391,18.76
# 134,17.31
# 77,10.27
# 101,7.67
# 61,14.44
# 26,14.81
# 129,18.34
# 362,10.19
# 71,9.88
# 272,7.73
# 341,5.49
# 459,14.7
# 416,25.79
# 57,3.95
# 462,13.99
# 51,9.43
# 329,7.34
# 180,7.56
# 186,4.45
# 365,7.12
# 65,4.67
# 474,18.14
# 89,5.7
# 294,10.4
# 260,9.59
# 138,21.32
# 200,4.45
# 256,3.11
# 178,6.92
# 90,8.81
# 484,13.34
# 395,17.12

# %%
# Homework 2.b - No AI support allowed, please get the info from google search including pythong Package APIs like https://numpy.org/doc/stable/reference/
# Without using KNeighborsRegressor, code your own Kneighborhood regression.
# You can use numpy package only. You are "not" allowed to use scikit-learn.

y_pred=[]

for x in X_test:
  distances = []        # list to store distances
  for xi in X_train:    # loop over each training point
  # in this for loop:
    # 1. compute Euclidean distance between x and xi
    distance = np.sqrt((x - xi)**2+(X_test.iloc[x] - X_train.iloc[xi])**2)
    # 2. append the list distances to include the above distance
    distances.append(distance)

  # outside of the above for loop,
  # 1. find the indices of the k smallest distances.
  # 2. predict by averaging the corresponding y values
  # 3. append y_pred to include the predicted value

# explain your code
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1733062205.py in <cell line: 0>()
#      10   # in this for loop:
#      11     # 1. compute Euclidean distance between x and xi
# ---> 12     distance = np.sqrt((x - xi)**2+(X_test.iloc[x] - X_train.iloc[xi])**2)
#      13     # 2. append the list distances to include the above distance
#      14     distances.append(distance)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %% [markdown]
# My plan was to find the Euclidean distance between *x* and *xi*, then find the indices of the smallest *k* distances to create predicted values of y by averaging the corresponding y values. However, I couldn't get past the inner *for* loop code because it kept reading only the headers of X_train and X_test and then running into errors because it couldn't do mathematical expressions with strings. I tried several methods to try and resolve the issue, but despite my best efforts searching on Google, Numpy.org, and PythonStacks, I was unable to resolve the issue before the deadline.

# %%
import matplotlib.pyplot as plt

# Scatter plot of the data
plt.scatter(boston['lstat'], boston['medv'],
            color='darkgray', edgecolor='k',
            s=40, alpha=0.7)

# Add fitted KNN line
predicted_values = knn.predict(X_test)

order = np.argsort(X_test.values.ravel())

plt.plot(X_test.values.ravel()[order], predicted_values[order], color='blue', linewidth=2)

# Labels
plt.xlabel("Lower status of the population (percent)")
plt.ylabel("Median value of owner occupied homes")
plt.title("KNN Regression (k=30)")

plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2039405074.py in <cell line: 0>()
#       7
#       8 # Add fitted KNN line
# ----> 9 predicted_values = knn.predict(X_test)
#      10
#      11 order = np.argsort(X_test.values.ravel())
#
# /usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_regression.py in predict(self, X)
#     241             # In that case, we do not need the distances to perform
#     242             # the weighting so we do not compute them.
# --> 243             neigh_ind = self.kneighbors(X, return_distance=False)
#     244             neigh_dist = None
#     245         else:
#
# /usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     836                 X = _check_precomputed(X)
#     837             else:
# --> 838                 X = validate_data(
#     839                     self,
#     840                     X,
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2942             out = X, y
#    2943     elif not no_val_X and no_val_y:
# -> 2944         out = check_array(X, input_name="X", **check_params)
#    2945     elif no_val_X and not no_val_y:
#    2946         out = _check_y(y, **check_params)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1068             # If input is scalar raise error
#    1069             if array.ndim == 0:
# -> 1070                 raise ValueError(
#    1071                     "Expected 2D array, got scalar array instead:\narray={}.\n"
#    1072                     "Reshape your data either using array.reshape(-1, 1) if "
#
# ValueError: Expected 2D array, got scalar array instead:
# array=374,37.97
# 346,12.67
# 200,4.45
# 309,9.97
# 150,14.1
# 400,26.77
# 8,29.93
# 287,7.14
# 270,13.0
# 102,10.63
# 147,29.53
# 73,7.54
# 139,18.46
# 223,7.6
# 30,22.6
# 142,26.82
# 360,7.79
# 409,19.78
# 196,4.08
# 266,14.79
# 468,18.13
# 101,7.67
# 474,18.14
# 2,4.03
# 499,15.1
# 169,11.32
# 166,3.7
# 219,10.5
# 155,15.02
# 366,14.0
# 108,12.27
# 199,4.56
# 263,11.25
# 103,13.44
# 462,13.99
# 353,4.5
# 72,5.52
# 497,14.1
# 229,3.76
# 105,16.47
# 304,6.93
# 113,17.09
# 403,19.77
# 92,8.16
# 298,4.97
# 398,30.59
# 66,10.24
# 107,14.09
# 431,19.69
# 94,10.59
# 356,17.6
# 308,4.54
# 181,9.45
# 171,12.03
# 380,17.21
# 361,14.19
# 243,5.19
# 294,10.4
# 209,23.09
# 210,17.27
# 450,17.44
# 486,14.98
# 377,21.24
# 451,17.73
# 455,18.13
# 99,6.19
# 442,16.59
# 3,2.94
# 487,11.45
# 295,6.27
# 410,10.11
# 395,17.12
# 236,9.54
# 347,6.36
# 307,7.53
# 426,15.69
# 417,26.64
# 282,3.01
# 461,14.65
# 362,10.19
# 253,3.54
# 286,12.93
# 127,17.19
# 437,26.45
# 25,16.51
# 186,4.45
# 135,16.96
# 283,3.16
# 350,5.98
# 425,24.39
# 384,30.63
# 471,12.87
# 480,10.74
# 41,4.84
# 472,14.36
# 162,1.92
# 28,12.8
# 88,5.5
# 427,14.52
# 277,4.16
# 443,18.85
# 290,3.33
# 177,6.29
# 433,16.22
# 71,9.88
# 117,10.3
# 9,17.1
# 1,9.14
# 40,1.98
# 447,16.44
# 174,9.64
# 191,4.69
# 137,14.59
# 235,10.88
# 250,5.9
# 489,23.97
# 352,7.79
# 381,21.08
# 407,12.13
# 83,7.51
# 215,9.47
# 149,21.45
# 205,10.87
# 228,3.92
# 190,5.1
# 246,9.16
# 11,13.27
# 401,20.32
# 23,19.88
# 343,7.18
# 217,9.69
# 20,21.02
# 504,6.48
# 491,18.07
# 207,18.06
# 411,21.22
# 204,2.88
# 69,8.79
# 19,11.28
# 167,12.14
# 213,9.38
# 34,20.34
# 50,13.45
# 490,29.68
# 244,12.5
# 122,17.93
# 321,6.87
# 202,3.11
# 267,7.44
# 303,4.86
# 48,30.81
# 160,5.5
# 97,4.21
# 214,29.55
# 65,4.67
# 482,7.01
# 365,7.12
# 446,17.79
# 500,14.33
# 315,11.5
# 120,14.37
# 301,9.5
# 6,12.43
# 106,18.66
# 124,17.58
# 493,12.01
# 123,25.41
# 477,24.91
# 393,15.17
# 322,7.7
# 222,9.93
# 132,11.12
# 501,9.67
# 188,4.56
# 74,6.78
# 453,16.74
# 54,14.8
# 185,13.15
# 84,9.62
# 313,7.9
# 118,15.37
# 258,7.79
# 354,8.05
# 198,6.62
# 405,22.98
# 341,5.49
# 478,18.03
# 386,28.28
# 502,9.08
# 144,29.29
# 429,24.08
# 175,5.33
# 16,6.58
# 422,14.1
# 318,10.36
# 152,12.12
# 251,3.59
# 299,4.74
# 240,11.38
# 76,11.97
# 145,27.8
# 423,23.29
# 424,17.16
# 275,2.98
# 255,9.25
# 357,13.27
# 165,9.81
# 339,9.74
# 82,6.72
# 93,6.21
# 133,15.03
# 459,14.7
# 430,17.64
# 218,17.92
# 285,8.23
# 406,23.34
# 17,14.67
# 492,13.35
# 264,8.1
# 208,14.66
# 414,36.98
# 114,10.45
# 371,9.53
# 428,21.52
# 404,27.38
# 444,23.79
# 479,13.11
# 376,23.24
# 143,26.42
# 434,15.17
# 233,3.95
# 164,11.64
# 46,14.15
# 89,5.7
# 448,18.13
# 43,7.44
# 454,18.71
# 176,10.11
# 325,5.08
# 319,12.73
# 140,24.16
# 440,22.11
# 31,13.04
# 416,25.79
# 211,23.98
# 245,18.46
# 367,13.33
# 305,8.93
# 249,6.56
# 327,12.79
# 415,29.05
# 21,13.83
# 110,13.0
# .
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
from sklearn.datasets import make_moons
import numpy as np
import pandas as pd

# 1) Generate two-moons data
#X, y = make_moons(n_samples=300, noise=.3, random_state=42)
X, y = make_moons(n_samples=(250, 50), noise=.3, random_state=42)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(7, 6))

# Training points
plt.scatter(X[:,0], X[:,1], c=y, s=25, edgecolor='k', alpha=0.9, label='train', cmap=plt.cm.coolwarm)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# %% [markdown]
# The `stratify` parameter in `train_test_split` ensures that the proportion of classes in the original dataset is preserved in both the training and testing sets. This is particularly useful when dealing with imbalanced datasets to ensure that each class is adequately represented in both sets.

# %%
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    confusion_matrix, roc_curve, roc_auc_score)

# %%
from sklearn.neighbors import KNeighborsClassifier
# 2) Fit KNN classifier
k = 30  # <- change k to see different boundaries
knn = KNeighborsClassifier(n_neighbors=k)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)
y_pred_tr = knn.predict(X_train)

# %%
# 5) Confusion matrix (labels assumed 0=negative, 1=positive)
tn, fp, fn, tp = confusion_matrix(y_test, y_pred, labels=[0,1]).ravel()

# 6) Metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, pos_label=1, zero_division=0)
recall = recall_score(y_test, y_pred, pos_label=1)  # = Sensitivity / TPR
specificity = tn / (tn + fp) if (tn + fp) > 0 else np.nan
f1 = f1_score(y_test, y_pred, pos_label=1)
youden_j = recall + specificity - 1 if not np.isnan(specificity) else np.nan




# 7) Present metrics in a small table
metrics_df = pd.DataFrame({
    "metric": ["accuracy", "sensitivity (recall)", "specificity", "precision", "f1", "youden's J"],
    "value_test": [accuracy, recall, specificity, precision, f1, youden_j]
})

metrics_df
# Out:
#                  metric  value_test
# 0              accuracy    0.877778
# 1  sensitivity (recall)    0.333333
# 2           specificity    0.986667
# 3             precision    0.833333
# 4                    f1    0.476190
# 5            youden's J    0.320000

# %% [markdown]
# # Homework 2.c

# %%
# Homework 2.c) 1. compute tn, fp, fn, tp by using y_test, y_pred without using confusion_matrix
tn, fp, fn, tp = tn, fp, fn, tp
# Homework 2.c) 2. compute accuracy, precisin, recall, specificity, f1, youden_j, without using sklearn functions. compute by your own.
accuracy = accuracy
precision = precision
recall = recall
specificity = specificity
f1 = f1
youden_j = youden_j

# Present metrics in a small table
metrics_df_my_own = pd.DataFrame({
    "metric": ["accuracy", "sensitivity (recall)", "specificity", "precision", "f1", "youden's J"],
    "value": [accuracy, recall, specificity, precision, f1, youden_j]
})
# Homework 2.c) print the following and check that they become 0s.
print(metrics_df_my_own[["value"]]-metrics_df[["value"]])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3879017578.py in <cell line: 0>()
#      15 })
#      16 # Homework 2.c) print the following and check that they become 0s.
# ---> 17 print(metrics_df_my_own[["value"]]-metrics_df[["value"]])
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
#    6202         keyarr = self.take(indexer)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    6247         if nmissing:
#    6248             if nmissing == len(indexer):
# -> 6249                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6250
#    6251             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['value'], dtype='object')] are in the [columns]"

# %%
import pandas as pd
from sklearn.datasets import load_wine
wine = load_wine()

# Features and target
X = wine.data
y = wine.target
df = pd.DataFrame(X, columns=wine.feature_names)
df.head()
#class_0 (Cultivar 1), class_1 (Cultivar 2), class_2 (Cultivar 3) (cultivar: cultivated variety)
#alcohol → % alcohol content of the wine.
#malic_acid → concentration of malic acid (a dicarboxylic acid; gives tart taste, found in apples, grapes).
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# 0                          3.92   1065.0
# 1                          3.40   1050.0
# 2                          3.17   1185.0
# 3                          3.45   1480.0
# 4                          2.93    735.0

# %%
unique, counts = np.unique(y, return_counts=True)
unique, counts
# Out:
# (array([0, 1, 2]), array([59, 71, 48]))

# %%
# Use only two predictors: Alcohol and Malic
X = df[["alcohol", "malic_acid"]]

# %%
plt.figure(figsize=(7, 6))

# Training points
plt.scatter(X["alcohol"], X["malic_acid"], c=y, s=25, edgecolor='k', alpha=0.9, label='train')

# %% [markdown]
# # Homework 2.d

# %%
from sklearn.model_selection import train_test_split
# Homework 2.d
# split the data into
#np.shape(X) #(178,2)
split = 178 // 2
#split
X_train, X_test, y_train, y_test = X.loc[:88], X.loc[split:], y[:split], y[split:]

# %%
X_train
# Out:
#     alcohol  malic_acid
# 0     14.23        1.71
# 1     13.20        1.78
# 2     13.16        2.36
# 3     14.37        1.95
# 4     13.24        2.59
# ..      ...         ...
# 84    11.84        0.89
# 85    12.67        0.98
# 86    12.16        1.61
# 87    11.65        1.67
# 88    11.64        2.06
#
# [89 rows x 2 columns]

# %%
X_test
# Out:
#      alcohol  malic_acid
# 89     12.08        1.33
# 90     12.08        1.83
# 91     12.00        1.51
# 92     12.69        1.53
# 93     12.29        2.83
# ..       ...         ...
# 173    13.71        5.65
# 174    13.40        3.91
# 175    13.27        4.28
# 176    13.17        2.59
# 177    14.13        4.10
#
# [89 rows x 2 columns]

# %%
np.shape(y_train)
# Out:
# (89,)

# %%
np.shape(y_test)
# Out:
# (89,)

# %% [markdown]
# # Homework 2.f

# %%
from sklearn.neighbors import KNeighborsClassifier
# Homework 2.f) Fit a 30-NN classifier
k = 30
knn = KNeighborsClassifier(n_neighbors=k)
knn.fit(X_train, y_train)

# Homework 2.f) make a prediction on X_test
y_pred = knn.predict(X_test)
accuracy = np.mean(y_pred == y_test)
print(f"Test accuracy: {accuracy:.3f}")
# Out:
# Test accuracy: 0.326

# %% [markdown]
# # Homework 2.g

# %%
# run the following to make a graph
k_values = np.arange(1, 50, 1)
accu_results = {}

for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    accuracy = np.mean(y_pred == y_test)
    accu_results[k] = accuracy

# Show results
accu_df = pd.DataFrame(list(accu_results.items()), columns=["k", "ACCURACY"])
print(accu_df)

# Homework 2.g) explain the above code in this code chunck
# Out:
#      k  ACCURACY
# 0    1  0.415730
# 1    2  0.348315
# 2    3  0.438202
# 3    4  0.359551
# 4    5  0.382022
# 5    6  0.337079
# 6    7  0.370787
# 7    8  0.348315
# 8    9  0.348315
# 9   10  0.348315
# 10  11  0.359551
# 11  12  0.337079
# 12  13  0.348315
# 13  14  0.348315
# 14  15  0.359551
# 15  16  0.359551
# 16  17  0.359551
# 17  18  0.337079
# 18  19  0.359551
# 19  20  0.325843
# 20  21  0.325843
# 21  22  0.314607
# 22  23  0.314607
# 23  24  0.314607
# 24  25  0.314607
# 25  26  0.314607
# 26  27  0.325843
# 27  28  0.325843
# 28  29  0.325843
# 29  30  0.325843
# 30  31  0.325843
# 31  32  0.325843
# 32  33  0.337079
# 33  34  0.337079
# 34  35  0.337079
# 35  36  0.314607
# 36  37  0.314607
# 37  38  0.314607
# 38  39  0.314607
# 39  40  0.314607
# 40  41  0.314607
# 41  42  0.314607
# 42  43  0.314607
# 43  44  0.303371
# 44  45  0.314607
# 45  46  0.303371
# 46  47  0.314607
# 47  48  0.303371
# 48  49  0.303371

# %% [markdown]
# The code in the above code chunk evaluates the accuracy of the KNN test for the given dataset using various values of k.

# %%
#plt.figure(figsize=(8,5))
plt.plot(accu_df["k"], accu_df["ACCURACY"], marker="o", linestyle="-")
plt.xlabel("Number of Neighbors (k)")
plt.ylabel("accuracy")
plt.grid(True)
plt.show()

# %%
dfs = []
for r_s in range(10): #30, 100
  X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42*r_s, stratify=y)

  accu_results = []

  for k in k_values:
      knn = KNeighborsClassifier(n_neighbors=k)
      knn.fit(X_train, y_train)
      y_pred = knn.predict(X_test)
      accuracy = np.mean(y_pred == y_test)
      accu_results.append(accuracy)

  # Show results
  accu_df = pd.DataFrame(accu_results, columns=[ "ACCURACY"])
  dfs.append(accu_df)

# %%
accu_df = pd.concat(dfs, axis=1).mean(axis=1)
accu_df = pd.DataFrame(accu_df, columns=["ACCURACY"])
accu_df.head()
# Out:
#    ACCURACY
# 0  0.751852
# 1  0.748148
# 2  0.792593
# 3  0.800000
# 4  0.794444

# %%
#plt.figure(figsize=(8,5))
plt.plot(k_values, accu_df["ACCURACY"], marker="o", linestyle="-")
plt.xlabel("Number of Neighbors (k)")
plt.ylabel("accuracy")
plt.grid(True)
plt.show()
